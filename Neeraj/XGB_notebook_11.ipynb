# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/30-days-of-ml/sample_submission.csv
# /kaggle/input/30-days-of-ml/train.csv
# /kaggle/input/30-days-of-ml/test.csv

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold

# %%
train = pd.read_csv("/kaggle/input/30-days-of-ml/train.csv")
test = pd.read_csv("/kaggle/input/30-days-of-ml/test.csv")
output = pd.read_csv("/kaggle/input/30-days-of-ml/sample_submission.csv")

# %%
train.head()
# Out:
#    id cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8  ...     cont5     cont6  \
# 0   1    B    B    B    C    B    B    A    E    C  ...  0.400361  0.160266
# 1   2    B    B    A    A    B    D    A    F    A  ...  0.533087  0.558922
# 2   3    A    A    A    C    B    D    A    D    A  ...  0.650609  0.375348
# 3   4    B    B    A    C    B    D    A    E    C  ...  0.668980  0.239061
# 4   6    A    A    A    C    B    D    A    E    A  ...  0.686964  0.420667
#
#       cont7     cont8     cont9    cont10    cont11    cont12    cont13  \
# 0  0.310921  0.389470  0.267559  0.237281  0.377873  0.322401  0.869850
# 1  0.516294  0.594928  0.341439  0.906013  0.921701  0.261975  0.465083
# 2  0.902567  0.555205  0.843531  0.748809  0.620126  0.541474  0.763846
# 3  0.732948  0.679618  0.574844  0.346010  0.714610  0.540150  0.280682
# 4  0.648182  0.684501  0.956692  1.000773  0.776742  0.625849  0.250823
#
#      target
# 0  8.113634
# 1  8.481233
# 2  8.364351
# 3  8.049253
# ...

# %%
test.head()
# Out:
#    id cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8  ...     cont4     cont5  \
# 0   0    B    B    B    C    B    B    A    E    E  ...  0.476739  0.376350
# 1   5    A    B    A    C    B    C    A    E    C  ...  0.285509  0.860046
# 2  15    B    A    A    A    B    B    A    E    D  ...  0.697272  0.683600
# 3  16    B    B    A    C    B    D    A    E    A  ...  0.719306  0.777890
# 4  17    B    B    A    C    B    C    A    E    C  ...  0.313032  0.431007
#
#       cont6     cont7     cont8     cont9    cont10    cont11    cont12  \
# 0  0.337884  0.321832  0.445212  0.290258  0.244476  0.087914  0.301831
# 1  0.798712  0.835961  0.391657  0.288276  0.549568  0.905097  0.850684
# 2  0.404089  0.879379  0.275549  0.427871  0.491667  0.384315  0.376689
# 3  0.730954  0.644315  1.024017  0.391090  0.988340  0.411828  0.393585
# 4  0.390992  0.408874  0.447887  0.390253  0.648932  0.385935  0.370401
#
#      cont13
# 0  0.845702
# 1  0.693940
# 2  0.508099
# 3  0.461372
# ...

# %%
features_train = train.drop(['target', 'id'], axis= 1)
features_test = test.drop(['id'], axis=1)
y = train['target']

# %%
features_train.shape
# Out:
# (300000, 24)

# %%
features_test.shape
# Out:
# (200000, 24)

# %%
from sklearn.preprocessing import OrdinalEncoder
object_cols = [col for col in features_train.columns if 'cat' in col ]

# %%
X = features_train.copy()
X_test = features_test.copy()
encoder = OrdinalEncoder()
X[object_cols] = encoder.fit_transform(features_train[object_cols])
X_test[object_cols] = encoder.transform(features_test[object_cols])
X.head()
# Out:
#    cat0  cat1  cat2  cat3  cat4  cat5  cat6  cat7  cat8  cat9  ...     cont4  \
# 0   1.0   1.0   1.0   2.0   1.0   1.0   0.0   4.0   2.0  13.0  ...  0.610706
# 1   1.0   1.0   0.0   0.0   1.0   3.0   0.0   5.0   0.0  14.0  ...  0.276853
# 2   0.0   0.0   0.0   2.0   1.0   3.0   0.0   3.0   0.0   5.0  ...  0.285074
# 3   1.0   1.0   0.0   2.0   1.0   3.0   0.0   4.0   2.0  10.0  ...  0.284667
# 4   0.0   0.0   0.0   2.0   1.0   3.0   0.0   4.0   0.0  13.0  ...  0.287595
#
#       cont5     cont6     cont7     cont8     cont9    cont10    cont11  \
# 0  0.400361  0.160266  0.310921  0.389470  0.267559  0.237281  0.377873
# 1  0.533087  0.558922  0.516294  0.594928  0.341439  0.906013  0.921701
# 2  0.650609  0.375348  0.902567  0.555205  0.843531  0.748809  0.620126
# 3  0.668980  0.239061  0.732948  0.679618  0.574844  0.346010  0.714610
# 4  0.686964  0.420667  0.648182  0.684501  0.956692  1.000773  0.776742
#
#      cont12    cont13
# 0  0.322401  0.869850
# 1  0.261975  0.465083
# ...

# %%
kfold = KFold(n_splits = 10, shuffle = True, random_state=42)
preds_valid = np.zeros((X.shape[0],))
preds_test = 0
mean_rmse = 0

for train_set, valid_set in kfold.split(X, y):
    X_train, X_valid = X.loc[train_set], X.loc[valid_set]
    y_train, y_valid = y.loc[train_set], y.loc[valid_set]
    
    model = XGBRegressor(n_estimators = 10000,
              learning_rate = 0.25,
              subsample = 0.926,
              colsample_bytree= 0.84,
              max_depth = 2,
              booster = 'gbtree', 
              reg_lambda = 35.1,
              reg_alpha = 34.9,
              random_state = 42,
              n_jobs = 4)
    model.fit(X_train, y_train,
             verbose = False,
             eval_set = [(X_train, y_train), (X_valid, y_valid)],
             eval_metric = "rmse",
             early_stopping_rounds = 100)
    
    preds_test += model.predict(X_test) / 10
    preds_valid[valid_set] = model.predict(X_valid)
    fold_rmse = np.sqrt(mean_squared_error(y_valid, preds_valid[valid_set]))
    mean_rmse += fold_rmse / 10
    
print("RMSE:", mean_rmse)
# Out:
# RMSE: 0.7168542405587779

# %%
output.target = preds_test
output.head()
# Out:
#    id    target
# 0   0  8.061050
# 1   5  8.388641
# 2  15  8.376623
# 3  16  8.504972
# 4  17  8.136312

# %%
output.to_csv('submission.csv', index=False)
print("successful")
# Out:
# successful
